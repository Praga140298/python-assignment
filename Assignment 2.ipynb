# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("youtube_dataset.csv",encoding="ISO-8859-1")
data.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
data_filtered = df[['userID', 'subscribers', 'channeltype']].copy()
data_filtered.head()
# Out:
#            userID  subscribers    channeltype
# 0       PewDiePie     90210848  Entertainment
# 1        T-Series     90194329          Music
# 2          Gaming     81888222          Games
# 3  YouTube Movies     77413743           Film
# 4          Sports     75622870         Sports

# %%
data_filtered = data.dropna(subset=['channeltype'])
data_filtered.head(50)
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0    1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1    1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2    1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3    1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4    1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# 5    1553043047-5143  https://socialblade.com/youtube/top/5000/mosts...
# 6    1553043043-5142  https://socialblade.com/youtube/top/5000/mosts...
# 7    1553043039-5141  https://socialblade.com/youtube/top/5000/mosts...
# 8    1553043035-5140  https://socialblade.com/youtube/top/5000/mosts...
# 9    1553043027-5138  https://socialblade.com/youtube/top/5000/mosts...
# 10   1553043023-5137  https://socialblade.com/youtube/top/5000/mosts...
# 11   1553043019-5136  https://socialblade.com/youtube/top/5000/mosts...
# ...

# %%
top_1000_data = data_filtered.nlargest(1000,"subscribers")

# %%
top_1000_data.head(50)
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0    1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1    1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2    1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3    1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4    1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# 5    1553043047-5143  https://socialblade.com/youtube/top/5000/mosts...
# 6    1553043043-5142  https://socialblade.com/youtube/top/5000/mosts...
# 7    1553043039-5141  https://socialblade.com/youtube/top/5000/mosts...
# 8    1553043035-5140  https://socialblade.com/youtube/top/5000/mosts...
# 9    1553043027-5138  https://socialblade.com/youtube/top/5000/mosts...
# 10   1553043023-5137  https://socialblade.com/youtube/top/5000/mosts...
# 11   1553043019-5136  https://socialblade.com/youtube/top/5000/mosts...
# ...

# %%
def channeltype_distribution(top_1000_data):
    distribution = data_filtered['channeltype'].value_counts(normalize=True) * 100  # Percentage distribution
    return distribution

# %%
channel_distribution = channeltype_distribution(top_1000_data)

# %%
channel_distribution
# Out:
# channeltype
# Entertainment    28.171692
# Music            20.646563
# Games            12.197772
# People           10.649280
# Comedy            7.470796
# Howto             6.058136
# Film              4.781309
# Education         3.857647
# Tech              2.118989
# Sports            1.521326
# News              1.494159
# Autos             0.380331
# Travel            0.298832
# Animals           0.244499
# Nonprofit         0.081500
# Shows             0.027167
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(12, 6))
channel_distribution.sort_values(ascending=False).plot(kind='bar', color='green')

# Labels and title
plt.xlabel("Channel Type")
plt.ylabel("Percentage (%)")
plt.title("Distribution of YouTube Channel Types (Top 1000)")
plt.xticks(rotation=50)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %%
output_file_path = "top_1000_youtube_channels1.csv"
top_1000_data.to_csv(output_file_path, index=False)

print(f"Top 1000 records saved to {output_file_path}")
# Out:
# Top 1000 records saved to top_1000_youtube_channels1.csv

# %%
#channel_distribution_df = channel_distribution.reset_index()
#channel_distribution_df.columns = ['Channel Type', 'Percentage (%)']
